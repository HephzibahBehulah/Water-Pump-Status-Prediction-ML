# %% [markdown]
# <!-- ===== Gradient Header ===== -->
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: center;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
#   💰 Water Pumps Prediction Group Sprint 1
# </p>
#
# <!-- ===== Meta Badges ===== -->
# <div style="display:flex; gap:12px; flex-wrap:wrap; font-family:'Montserrat',sans-serif; margin: 0 2px 16px;">
#   <span style="background:#fff4f0; border:1px solid #ffd8c2; color:#68391f;
#                padding:8px 14px; border-radius:999px; font-size:18px; box-shadow:0 2px 8px rgba(0,0,0,0.05);">
#     👤 <b>Author:</b> Hydro Dominion
#   </span>
#   <span style="background:#f0f7ff; border:1px solid #cde2ff; color:#1f3b68;
#                padding:8px 14px; border-radius:999px; font-size:13px; box-shadow:0 2px 8px rgba(0,0,0,0.05);">
#     🌳 <b>Project Type:</b> Binary Classification
#   </span>
#   <span style="background:#f9f9f9; border:1px solid #d1d1d1; color:#3b3b3b;
#                padding:8px 14px; border-radius:999px; font-size:13px; box-shadow:0 2px 8px rgba(0,0,0,0.05);">
#     ⏱️ <b>Duration:</b> 3 Weeks
#   </span>
#     <span style="background:#f9f9f9; border:1px solid #d1d1d1; color:#3b3b3b;
#                padding:8px 14px; border-radius:999px; font-size:13px; box-shadow:0 2px 8px rgba(0,0,0,0.05);">
#     ⏱️ <b>School:</b> ReDI Data Circle 2026
#   </span>
# </div>

# %% [markdown]
# ### `Task Description`
# Can you predict which water pumps are faulty to promote access to clean, potable water across Tanzania?
# This is an intermediate-level practice competition.
# ---
#
# - Build a model to predict whether a water pump is faulty.
# - Handle missing values and encode categorical features.
# - Train a classification model and evaluate performance on imbalanced data
# - Focus on precision, recall, and F1-score
# - Dataset : [Pump it Up: Data Mining the Water Table](https://www.drivendata.org/competitions/7/pump-it-up-data-mining-the-water-table/data/).
# - GitHub Colab: https://github.com/HephzibahBehulah/Water-Pump-Prediction
#
# ---
# ### `Approach`
# We'll build 6 models which are Logistic Regression, Decision Tree, Random forest, XGBoost, LightGBM and CastBoost for more precision

# %% [markdown]
# ### `The labels in this dataset`
#
# The labels in this dataset are simple. There are three possible values:
# - functional - the waterpoint is operational and there are no repairs needed
# - functional needs repair - the waterpoint is operational, but needs repairs
# - non functional - the waterpoint is not operational
#
# ### `The features in this dataset`
# - Your goal is to predict the operating condition of a water point for each record in the dataset.
# - You are provided the following set of information about the water points:
#
# --
#
# - amount_tsh - Total static head (amount water available to water point)
# - date_recorded - The date the row was entered
# - funder - Who funded the well
# - gps_height - Altitude of the well
# - installer - Organization that installed the well
# - longitude - GPS coordinate
# - latitude - GPS coordinate
# - wpt_name - Name of the water point if there is one
# - num_private -
# - basin - Geographic water basin
# - subvillage - Geographic location
# - region - Geographic location
# - region_code - Geographic location (coded)
# - district_code - Geographic location (coded)
# - lga - Geographic location
# - ward - Geographic location
# - population - Population around the well
# - public_meeting - True/False
# - recorded_by - Group entering this row of data
# - scheme_management - Who operates the water point
# - scheme_name - Who operates the water point
# - permit - If the water point is permitted
# - construction_year - Year the water point was constructed
# - extraction_type - The kind of extraction the water point uses
# - extraction_type_group - The kind of extraction the water point uses
# - extraction_type_class - The kind of extraction the water point uses
# - management - How the water point is managed
# - management_group - How the water point is managed
# - payment - What the water costs
# - payment_type - What the water costs
# - water_quality - The quality of the water
# - quality_group - The quality of the water
# - quantity - The quantity of water
# - quantity_group - The quantity of water
# - source - The source of the water
# - source_type - The source of the water
# - source_class - The source of the water
# - water point_type - The kind of water point
# - water point_type_group - The kind of water point
#
# --

# %% [markdown]
# # Sprint 1: Exploratory Data Analysis - REDI REQUIREMENT
# **Week 1–3**
#
# ### Overview
# In this sprint, teams will focus on understanding the dataset, cleaning the data, and preparing it for modeling. The goal is to gain insights into water pump functionality patterns and identify potentially important features.
#
# 1. Set up project environment, GitHub repository, and documentation
#
# 2. Define your hypotheses. For example:
# - Pump type influences functionality
# - The installer affects pump reliability
# - Geography impacts pump functionality
# - Pump age correlates with failure
#
# 3. Define research questions. For example:
# - Do older pumps fail more often?
# - Are pumps serving larger populations more likely to break?
# - Are pumps in certain regions or basins more likely to fail?
# - How does the installer relate to long-term functionality?
# - Which pump types have the highest proportion of functional pumps?
#
# 4. Clean and prepare the data. It may include the following steps:
# - Validate consistency and data quality
# - Remove duplicate entries and entries with missing values for the dependent variable
# - Explore outliers
# - Reorganise categorical variables with many categories
# - Any other steps you find necessary to complete
#
# ### Deliverables
# - Hypothesis and research questions
# - Key insights and visualizations
# - Reproducible scripts and documentation
# - Pitch-presentation (5-minute presentation of results achieved in this sprint)

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: center;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
# Import Libaries
#  </p>

# %%
# Standard libraries
import warnings
from typing import Any, Dict, Optional, Tuple
# Data handling
import numpy as np
import pandas as pd
# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
# Machine Learning libraries
import catboost
import lightgbm as lgb
import xgboost as xgb
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
# Imbalanced data handling
from imblearn.over_sampling import SMOTE
# Scikit-learn
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import (
    GridSearchCV,
    cross_val_score,
    train_test_split,
)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OrdinalEncoder
from catboost import CatBoostClassifier
# Warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: center;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
# 1. Load Dataset
#  </p>

# %%
#read in csv's and merge
values_df = pd.read_csv('Training Set Values.csv')
labels_df = pd.read_csv('Training Set Labels.csv')
test_df = pd.read_csv('Test Set Values.csv')

df= pd.merge(values_df, labels_df, on = 'id' )

print("Train shape:", df.shape)
print("Test shape:", test_df.shape)

df.head()

# %%
#read in csv's and merge
values_df = pd.read_csv('Training Set values.csv')
labels_df = pd.read_csv('Training Set Labels.csv')
test_df = pd.read_csv('Test Set Values.csv')

df= pd.merge(values_df, labels_df, on = 'id' )


# print("Train shape:", df.shape)
# print("Test shape:", test_df.shape)

df.head()

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: center;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
# 2. Hypotheses
#  </p>

# %%
# Hydro Dominion Hypotheses:

# H1: Pump type influences functionality  
# H2: Installer affects pump reliability  
# H3: Geography (region/basin) impacts pump performance  
# H4: Older pumps are more likely to fail  
# H5: Population served influences pump failure rate  
# H6: Water quality affects pump functionality
# H7: Maintenance frequency impacts pump reliability
# H8: Pump age and installer together influence failure rates
# H9: Certain pump types are more prone to failure in specific regions
# H10: Socioeconomic factors of the area affect pump maintenance and functionality

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: center;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
# 3. EDA and Before Pre Processing
#  </p>

# %%
# --- BEFORE CLEANING ---
print("=== BEFORE CLEANING ===\n")

# Basic info
print("=== DataFrame Info ===")
df.info()
print("\n=== Data Types ===")
print(df.dtypes)
print("\n=== Shape ===")
print(df.shape)

# Summary statistics
print("\n=== Summary Statistics ===")
display(df.describe(include='all'))  # include categorical columns

# Missing values
print("\n=== Missing Values ===")
print(df.isnull().sum())
print("\n=== Any NA? ===")
print(df.isna().any())
print("\n=== Total columns with NA ===")
print(df.isna().any().sum())

# Duplicates
print("\n=== Duplicated Rows ===")
print(f'Duplicated = {df.duplicated().sum()}')

# Unique values per column
print("\n=== Unique Values per Column ===")
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")

# Target variable distribution
print("\n=== Target Variable Distribution ===")
print(df['status_group'].value_counts())

# %%
# OUTLIER CHECK BEFORE CLEANING
# Select numeric columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

print("=== OUTLIER CHECK BEFORE CLEANING ===\n")

for col in num_cols:
    plt.figure(figsize=(6, 4))
    sns.boxplot(y=df[col])
    plt.title(f"Outliers in {col} (Before Cleaning)")
    plt.show()

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: center;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
# EDA and Pre Processing
#  </p>

# %%
# ---- 0. Columns with data types ----
col_types = {}
for col in df.columns:
    types = df[col].apply(type).value_counts()
    col_types[col] = {str(t): n for t, n in types.items()}
col_types

# %%
# ---- 1. Missing value check before cleaning data ----
print(f'Missing value = {df.isnull().sum()}') # => missing value

print("Train missing:\n", df.isnull().sum().sum())
print("Test missing:\n", test_df.isnull().sum().sum())

# %%
# ---- 2 Identify columns ----
numeric_cols = ['amount_tsh','gps_height','longitude','latitude','num_private',
                'population','construction_year']

categorical_cols = ['funder','installer','wpt_name','subvillage',
                    'public_meeting','scheme_management','scheme_name','permit']

# %%
# --- 3. Identify target and features ---
target_col = 'status_group'
X = df.drop(columns=[target_col, 'id'])
y = df[target_col]
X_test = test_df.drop(columns=['id'])

# --- 4. Identify categorical columns ---
cat_cols = X.select_dtypes(include=['object']).columns

# %%
# --- 5. Fix mixed types in categorical columns ---
for col in cat_cols:
    X[col] = X[col].astype(str).fillna('missing')
    X_test[col] = X_test[col].astype(str).fillna('missing')

# --- 6. Fill missing numeric values with 0 ---
num_cols = X.select_dtypes(include=['int', 'float']).columns
X[num_cols] = X[num_cols].fillna(0)
X_test[num_cols] = X_test[num_cols].fillna(0)

# %%
# --- 7. Encode categorical variables ---
encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
X[cat_cols] = encoder.fit_transform(X[cat_cols])
X_test[cat_cols] = encoder.transform(X_test[cat_cols])

# %%
# --- 8. Lock in cleaned data ---
def clean_data(data):
    # Fill categorical
    cat_cols = data.select_dtypes(include='object').columns
    for col in cat_cols:
        data[col] = data[col].fillna('missing')
    
    # Fill numerical
    num_cols = data.select_dtypes(include=['int64','float64']).columns
    for col in num_cols:
        data[col] = data[col].fillna(0)
    
    return data

# %%
# --- 9. Clean Data-- 
df = clean_data(df)
test_df = clean_data(test_df)

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: center;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
# 3. EDA and After Pre Processing
#  </p>

# %%
# --- AFTER CLEANING ---
print("=== AFTER CLEANING ===\n")

# Check cleaned dataframe (X or df_clean)
print("=== DataFrame Info ===")
X.info()
print("\n=== Data Types ===")
print(X.dtypes)
print("\n=== Shape ===")
print(X.shape)

# Summary statistics
print("\n=== Summary Statistics ===")
display(X.describe(include='all'))

# Missing values
print("\n=== Missing Values ===")
print(X.isnull().sum())
print("\n=== Any NA? ===")
print(X.isna().any())
print("\n=== Total columns with NA ===")
print(X.isna().any().sum())

# Duplicates
print("\n=== Duplicated Rows ===")
print(f'Duplicated = {X.duplicated().sum()}')

# Unique values per column
print("\n=== Unique Values per Column ===")
for col in X.columns:
    print(f"{col}: {X[col].nunique()} unique values")

# Target variable distribution (if included in cleaned data)
if 'status_group' in X.columns:
    print("\n=== Target Variable Distribution ===")
    print(X['status_group'].value_counts())
    
# Missing value check before cleaning data ----
print(f'Missing value = {df.isnull().sum()}') # => missing value

print("Train missing:\n", df.isnull().sum().sum())
print("Test missing:\n", test_df.isnull().sum().sum())

# %%
# OUTLIER CHECK AFTER CLEANING
 # Select numeric columns

print("=== OUTLIER CHECK AFTER CLEANING ===\n")

for col in num_cols:
    plt.figure(figsize=(6, 4))
    sns.boxplot(y=df[col])
    plt.title(f"Outliers in {col} (After Cleaning)")
    plt.show()

# %%
# ---- Drop useless columns ----
# drop_cols = ['id', 'recorded_by', 'wpt_name', 'scheme_name']
# df.drop(columns=drop_cols, inplace=True)
# test_df.drop(columns=drop_cols, inplace=True)

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: center;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
# 4. EDA and Visualisation
#  </p>

# %%
# Target Distribution
plt.figure(figsize=(6,4))
sns.countplot(x='status_group', data=df)
plt.title("Pump Status Distribution")
plt.xticks(rotation=20)
plt.show()

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: center;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
# 5. Hypotheses Analysis
#  </p>

# %%
# 1: Pump Age vs Failure
df['pump_age'] = 2026 - df['construction_year']

plt.figure(figsize=(8,5))
sns.histplot(data=df, x='pump_age', hue='status_group', multiple='stack', bins=30)
plt.title("Pump Age Distribution by Status")
plt.xlabel("Pump Age (Years)")
plt.ylabel("Count")
plt.show()

df['pump_age'] = 2026 - df['construction_year']
plt.figure(figsize=(6,4))
sns.boxplot(x='status_group', y='pump_age', data=df)
plt.title("H1: Pump Age vs Status")
plt.show()

# %%
# 2: Region and Basin Impact
# Region
plt.figure(figsize=(12,5))
sns.countplot(y='region', hue='status_group', data=df)
plt.title("H3: Pump Status by Region")
plt.show()

# Basin
plt.figure(figsize=(10,5))
sns.countplot(y='basin', hue='status_group', data=df)
plt.title("H3: Pump Status by Basin")
plt.show()


plt.figure(figsize=(12,6))
sns.countplot(y='region', hue='extraction_type', data=df[df['status_group']=='non functional'])
plt.title("H2: Non-Functional Pump Types by Region")
plt.show()

# %%
# 4:Installer Effect
top_installers = df['installer'].value_counts().head(10).index

plt.figure(figsize=(10,5))
sns.countplot(
    y=df[df['installer'].isin(top_installers)]['installer'],
    hue=df['status_group']
)
plt.title("Top Installers vs Pump Status")
plt.show()

# %%
# 5: Population Impact 
plt.figure(figsize=(6,4))
sns.boxplot(x='status_group', y='population', data=df)
plt.title("Population vs Pump Status")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='status_group', y='population', data=df)
plt.ylim(0, 2000)  # focus on realistic population range
plt.title("Population vs Pump Status (Zoomed)")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.stripplot(x='status_group', y='population', data=df, jitter=True, alpha=0.5)
plt.ylim(0, 2000)
plt.title("Population vs Pump Status (Jittered)")
plt.show()

# %%
# 6: Pump Type
plt.figure(figsize=(10,5))
sns.countplot(y='extraction_type', hue='status_group', data=df)
plt.title("Pump Type vs Status")
plt.show()

# %%
# 7: Water Quality Affects Pump Functionality
plt.figure(figsize=(10,5))
sns.countplot(y='water_quality', hue='status_group', data=df)
plt.title("H6: Water Quality vs Pump Status")
plt.show()

# %%
# 8: Maintenance Frequency Impacts Reliability
plt.figure(figsize=(10,5))
sns.countplot(y='public_meeting', hue='status_group', data=df)
plt.title("H8: Public Meeting (Maintenance Proxy) vs Pump Status")
plt.show()

# %%
# 9: Pump Age & Installer Together Influence Failure Rates
top_installers = df['installer'].value_counts().head(10).index
plt.figure(figsize=(12,6))
sns.boxplot(x='installer', y='pump_age', hue='status_group', 
            data=df[df['installer'].isin(top_installers)])
plt.title("H9: Pump Age & Installer vs Status")
plt.xticks(rotation=45)
plt.show()

# %%
# 9: Socioeconomic Factors (Population/Permit/Management)
plt.figure(figsize=(6,4))
sns.boxplot(x='status_group', y='population', data=df)
plt.title("H10: Population as Socioeconomic Proxy vs Status")
plt.show()

plt.figure(figsize=(10,5))
sns.countplot(y='management_group', hue='status_group', data=df)
plt.title("H10: Management Group vs Pump Status")
plt.show()

plt.figure(figsize=(10,5))
sns.countplot(y='permit', hue='status_group', data=df)
plt.title("H10: Permit Status vs Pump Status")
plt.show()

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: center;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
# 6. Outlier Analysis
#  </p>

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df['amount_tsh'])
plt.title("Outliers in Water Amount")
plt.show()

plt.figure(figsize=(6,4))
sns.boxplot(x=df['amount_tsh'])
plt.xlim(0, 200)  # focus on realistic range
plt.title("Outliers in Water Amount (Zoomed)")
plt.show()


plt.figure(figsize=(6,4))
sns.boxplot(x=np.log1p(df['amount_tsh']))  # log(1 + x) to avoid log(0)
plt.title("Outliers in Water Amount (Log Scale)")
plt.show()

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: center;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
# 7. Correlation
#  </p>

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: center;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
# 8. KEY INSIGHTS
#  </p>

# %%
# 1. Older pumps are more likely to be non-functional ✔️  
# 2. Geography (region & basin) strongly affects pump status ✔️  
# 3. Installer plays a major role in reliability ✔️  
# 4. Certain pump types perform better ✔️  
# 5. Population pressure contributes to failures ✔️  
# 6. Dataset is imbalanced (few pumps need repair) ⚠️

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: center;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
# Split data to Train & Test</p>

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: center;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
# Five Models Training</p

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: left;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
# 1. Logistic Regression
#  </p>

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: left;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
#  📉 Confusion Matrix
#  </p>

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: left;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
#  📊 Feature Importance
#  </p>

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: left;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
#  🔍 Correlation Heatmap
#  </p>

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: left;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
# 2. Decision Tree
#  </p>

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: left;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
# Plot Tree
#  </p>

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: left;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
# 3. Random Forest
#  </p>

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: left;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
# 4. XGBoost
#  </p>

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: left;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
# 5. LightGBM
#  </p>

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: left;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
# 6. CatBoost
#  </p>

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: left;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
# Compare 6 Models
#  </p>

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: center;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
# 🎯 Conclusion & Key Takeaways
#  </p>

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: center;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
# Thank you und Vielen Dank @ ReDI 2026 Data Circle
#  </p>
